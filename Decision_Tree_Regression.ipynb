# %% [markdown]
# <a href="https://colab.research.google.com/github/RakeshBB08/MachineLearning/blob/master/Decision_Tree_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("/content/Position_Salaries.csv")
X = dataset.iloc[:,1:-1].values
y = dataset.iloc[:,-1].values

# %%
# Training the whole dataset
from sklearn.tree import DecisionTreeRegressor
DT_reg = DecisionTreeRegressor(random_state = 0)
DT_reg.fit(X,y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# predict
y_pred = DT_reg.predict([[6.5]])
y_pred
# Out:
# array([150000.])

# %%
# scatter plt with high resolution
X_grid = np.arange(min(X),max(X),0.1)
X_grid = X_grid.reshape(len(X_grid),1)
plt.scatter(X,y,color = "red")
plt.plot(X_grid,DT_reg.predict(X_grid),color = "blue")
plt.title("Truth vs Bluff [Decision Tree Regression]")
plt.xlabel("Position level")
plt.ylabel("Salary")
plt.show()
